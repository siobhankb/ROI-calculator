# %% [markdown]
# ### ROI Calculator
#
# #### Income types
# - rental income
# - laundry
# - storage
# - miscellaneous
#
# #### Expenses
# - tax
# - insurance
# - utilities (electric, gas, water, sewer, garbage)
# - HOA fees
# - Lawn or Snow services
# - Vacancy cost
# - Repairs
# - Capital Expenditures (saving for roof, water heater, appliances, exterior painting, etc)
# - Property management
# - Mortgage
#
# #### Cash Flow
# - --> Income - Expenses <--
#
# #### Cash on Cash Return on Investment
# - Down Payment
# - Closing costs
# - Rehab budget
# - Misc/other
# ^ add these up to find total investment
#
#
# #### Calculate ROI:
# ** Monthly cash flow X 12
# ** Annual cash flow / total investment
# (multiply result by 100 to display as a percent)

# %%
class ROI:
    def __init__(self):
        self.income = 0
        self.expenses = 0
        self.investment = 0
        self.roi = 0       

    def get_income(self):
        income_inputs = {}
        print("\nUse only whole numbers with no commas or periods.\nIf none, type 0.\n")
        income_inputs['rental']= input("Rental income: ")
        income_inputs['laundry']= input("Laundry income: ")
        income_inputs['storage']= input("Storage income: ")
        income_inputs['misc']= input("Miscellaneous income: ")
        for key, value in income_inputs.items():
            if income_inputs[key] == '':
                income_inputs[key] = 0
            self.income += int(value)
        print(income_inputs)
        print(self.income)
        print(f"\nYour total monthly income is:\n\t${self.income}\n")

    def get_expenses(self):
        exp_inputs = {}
        print("\nUse only whole numbers with no commas or periods.\nIf none, type 0.\n")
        exp_inputs['mortgage']= input("Mortgage payment: ")
        exp_inputs['tax']= input("Property taxes: ")
        exp_inputs['insurance']= input("Insurance: ")
        exp_inputs['utilities']= input("Utilities: ")
        exp_inputs['hoa']= input("HOA fees: ")
        exp_inputs['lawn']= input("Lawn and/or snow services: ")
        exp_inputs['vacancy']= input("Vacancy costs: ")
        exp_inputs['repairs']= input("Repairs: ")
        exp_inputs['capital expenditures']= input("Capital expenditures: ")
        exp_inputs['property management']= input("Property Management: ")
        for key, value in exp_inputs.items():
            if exp_inputs[key] == '':
                exp_inputs[key] = 0
            self.expenses += int(value)
        print(f"\nYour total monthly expenses are:\n\t{self.expenses}\n")

    def get_investment(self):
        inv_inputs = {}
        print("\nUse only whole numbers with no commas or periods.\nIf none, type 0.\n")
        inv_inputs['dn_payment']= input("Down payment: ")
        inv_inputs['closing']= input("Closing costs: ")
        inv_inputs['rehab']= input("Remodel costs: ")
        inv_inputs['misc']= input("Miscellaneous costs: ")
        for key, value in inv_inputs.items():
            if inv_inputs[key] == '':
                inv_inputs[key] = 0
            self.investment += int(value)
        print(f"\nYour total invesment is:\n\t{self.investment}\n")


    def update_info(self):
        while True:
            print("Which information you would like to update?\n")
            update_ask = input("1. Income \
            2. Expenses \
            3. Investments\n")
            if update_ask == '1':
                self.get_income()
            elif update_ask == '2':
                self.get_expenses()
            elif update_ask == '3':
                self.get_investment()
            else:
                update_ask = input("Please type a number: \
                1. Income \
                2. Expenses \
                3. Investments")
            ask = input("Would you like to update other information? (y/n) ")
            if ask == 'n':
                break
        self._roi()
    
    def _roi(self):
        import time
        time.sleep(3)
        annual_cash = (self.income - self.expenses) * 12
        self.roi = round((annual_cash / self.investment) * 100, 2)
        print(f"\nYour projected Return on Investment is {self.roi}%\n")
        
def run_roi():
    import time
    print("Welcome to Bigger Pockets ROI Calculator!\nWe'll take you step-by-step to find your projected real estate profits\n")
    z = ROI()
    print("Let's start with your INVESTMENTS.\n")
    z.get_investment()
    time.sleep(2)
    print("Now let's look at your monthly INCOME.\n")
    z.get_income()
    time.sleep(2)
    print("Finally, we'll go through your monthly EXPENSES")
    z.get_expenses()
    time.sleep(2)
    print("\nWhew! Thanks for all that information! Let's calculate your Return on Investment...")
    time.sleep(2)
    z._roi()
    while True:
        print("What do you think?")
        more = input("1. This is great! I'm ready to roll!\n2. I want to change some information...")
        while more not in {'1', '2'}:
            print("We'd love to stay and play all day, but we know you have money to make!")
            more = input("Please choose:\n1. I have all the information I need. (exits the calculator)\n2. I want to change some things to see if I can make more money! (keep working...)")
        if more == '1':
            print("\nThanks for using Bigger Pockets ROI Calculator! Best of luck to you!")
            break
        elif more == '2':
            z.update_info()

# %%
x = ROI()
income = x.get_income()
print(income)
# Out:
# Use only whole numbers with no commas or periods.
# If none, type 0.
#
# Rental income: 2000
# Laundry income:
# Storage income:
# Miscellaneous income:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [52], in <cell line: 2>()
#       1 x = ROI()
# ----> 2 income = x.get_income()
#       3 print(income)
#
# Input In [51], in ROI.get_income(self)
#      16     if income_inputs[key] == '':
#      17         income_inputs[key] = 0
# ---> 18     self.income += int(value)
#      19 print(income_inputs)
#      20 print(self.income)
#
# ValueError: invalid literal for int() with base 10: ''

# %%
# my_house = ROI()
# my_house.income()
# print(my_house.roi['income'])

# %%
run_roi()
# Out:
# Welcome to Bigger Pockets ROI Calculator!
# We'll take you step-by-step to find your projected real estate profits
#
# Let's start with your INVESTMENTS.
#
#
# Use only whole numbers with no commas or periods.
# If none, type 0.
#
# Down payment: 12000
# Closing costs: 4000
# Remodel costs: 2000
# Miscellaneous costs:
#
# Your total invesment is:
# 	18000
#
# Now let's look at your monthly INCOME.
#
#
# Use only whole numbers with no commas or periods.
# If none, type 0.
#
# Rental income: 2400
# Laundry income:
# Storage income: 100
# Miscellaneous income:
#
# Your total monthly income is:
# 	$2500
#
# Finally, we'll go through your monthly EXPENSES
#
# Use only whole numbers with no commas or periods.
# If none, type 0.
#
# Mortgage payment: 1600
# Property taxes: 120
# Insurance: 100
# Utilities: 100
# HOA fees:
# Lawn and/or snow services:
# Vacancy costs: 100
# Repairs: 100
# Capital expenditures: 100
# Property Management:
#
# Your total monthly expenses are:
# 	2220
#
#
# Whew! Thanks for all that information! Let's calculate your Return on Investment...
#
# Your projected Return on Investment is 18.67%
#
# What do you think?
# 1. This is great! I'm ready to roll!
# 2. I want to change some information...2
# Which information you would like to update?
#
# 1. Income             2. Expenses             3. Investments
# 1
#
# Use only whole numbers with no commas or periods.
# If none, type 0.
#
# Rental income: 2000
# Laundry income:
# Storage income: 100
# Miscellaneous income:
#
# Your total monthly income is:
# 	$4600
#
# Would you like to update other information? (y/n) n
#
# Your projected Return on Investment is 158.67%
#
# What do you think?
# 1. This is great! I'm ready to roll!
# 2. I want to change some information...1
#
# Thanks for using Bigger Pockets ROI Calculator! Best of luck to you!
